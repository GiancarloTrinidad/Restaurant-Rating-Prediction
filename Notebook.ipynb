# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Dataset .csv')

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
# Remove outliers
df = df[df["Average Cost for two"] < 70000]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9530 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9530 non-null   int64
#  1   Restaurant Name       9530 non-null   object
#  2   Country Code          9530 non-null   int64
#  3   City                  9530 non-null   object
#  4   Address               9530 non-null   object
#  5   Locality              9530 non-null   object
#  6   Locality Verbose      9530 non-null   object
#  7   Longitude             9530 non-null   float64
#  8   Latitude              9530 non-null   float64
#  9   Cuisines              9521 non-null   object
#  10  Average Cost for two  9530 non-null   int64
#  11  Currency              9530 non-null   object
#  12  Has Table booking     9530 non-null   object
#  13  Has Online delivery   9530 non-null   object
#  14  Is delivering now     9530 non-null   object
# ...

# %%
# Remove all not rated entries
df = df[df["Rating text"] != "Not rated"]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7382 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         7382 non-null   int64
#  1   Restaurant Name       7382 non-null   object
#  2   Country Code          7382 non-null   int64
#  3   City                  7382 non-null   object
#  4   Address               7382 non-null   object
#  5   Locality              7382 non-null   object
#  6   Locality Verbose      7382 non-null   object
#  7   Longitude             7382 non-null   float64
#  8   Latitude              7382 non-null   float64
#  9   Cuisines              7373 non-null   object
#  10  Average Cost for two  7382 non-null   int64
#  11  Currency              7382 non-null   object
#  12  Has Table booking     7382 non-null   object
#  13  Has Online delivery   7382 non-null   object
#  14  Is delivering now     7382 non-null   object
# ...

# %%
df["Country Code"].value_counts()
# Out:
# Country Code
# 1      6513
# 216     431
# 215      79
# 214      60
# 189      60
# 30       55
# 148      40
# 208      34
# 14       24
# 162      22
# 166      20
# 184      20
# 191      20
# 37        4
# Name: count, dtype: int64

# %% [markdown]
# Data Visualization

# %%
df.groupby("City")["Average Cost for two"].mean().sort_values(ascending=False).head().plot(kind='bar')
plt.title("Top 5 Cities based on Average Cost per two people")
plt.xlabel("City")
plt.ylabel("Amount")
plt.show()

# %%
df.plot(kind="scatter", x="Aggregate rating", y="Average Cost for two")
plt.show()

# %%
sns.pairplot(df[["Average Cost for two", "Aggregate rating", "Votes"]])

# %%
df["Has Online delivery"].value_counts().plot(kind='pie')
plt.title("Has Online Delivery")
plt.ylabel("")
plt.legend()
plt.show()

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7382 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         7382 non-null   int64
#  1   Restaurant Name       7382 non-null   object
#  2   Country Code          7382 non-null   int64
#  3   City                  7382 non-null   object
#  4   Address               7382 non-null   object
#  5   Locality              7382 non-null   object
#  6   Locality Verbose      7382 non-null   object
#  7   Longitude             7382 non-null   float64
#  8   Latitude              7382 non-null   float64
#  9   Cuisines              7373 non-null   object
#  10  Average Cost for two  7382 non-null   int64
#  11  Currency              7382 non-null   object
#  12  Has Table booking     7382 non-null   object
#  13  Has Online delivery   7382 non-null   object
#  14  Is delivering now     7382 non-null   object
# ...

# %%
df["Rating text"].value_counts().plot(kind="pie")
plt.title("Average ratings")
plt.ylabel("")
plt.show()

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
X = df[["Average Cost for two", "Has Table booking", "Has Online delivery", "Price range"]]
y = df[["Aggregate rating"]]

# %%
X
# Out:
#       Average Cost for two Has Table booking Has Online delivery  Price range
# 0                     1100               Yes                  No            3
# 1                     1200               Yes                  No            3
# 2                     4000               Yes                  No            4
# 3                     1500                No                  No            4
# 4                     1500               Yes                  No            4
# ...                    ...               ...                 ...          ...
# 9546                    80                No                  No            3
# 9547                   105                No                  No            3
# 9548                   170                No                  No            4
# 9549                   120                No                  No            4
# 9550                    55                No                  No            2
#
# [7382 rows x 4 columns]

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

# %%
X["Has Table booking"] = labelencoder.fit_transform(X["Has Table booking"])

# %%
X
# Out:
#       Average Cost for two  Has Table booking Has Online delivery  Price range
# 0                     1100                  1                  No            3
# 1                     1200                  1                  No            3
# 2                     4000                  1                  No            4
# 3                     1500                  0                  No            4
# 4                     1500                  1                  No            4
# ...                    ...                ...                 ...          ...
# 9546                    80                  0                  No            3
# 9547                   105                  0                  No            3
# 9548                   170                  0                  No            4
# 9549                   120                  0                  No            4
# 9550                    55                  0                  No            2
#
# [7382 rows x 4 columns]

# %%
X["Has Online delivery"] = labelencoder.fit_transform(X["Has Online delivery"])

# %%
X
# Out:
#       Average Cost for two  Has Table booking  Has Online delivery  \
# 0                     1100                  1                    0
# 1                     1200                  1                    0
# 2                     4000                  1                    0
# 3                     1500                  0                    0
# 4                     1500                  1                    0
# ...                    ...                ...                  ...
# 9546                    80                  0                    0
# 9547                   105                  0                    0
# 9548                   170                  0                    0
# 9549                   120                  0                    0
# 9550                    55                  0                    0
#
#       Price range
# 0               3
# 1               3
# 2               4
# 3               4
# 4               4
# ...           ...
# 9546            3
# ...

# %% [markdown]
# For table booking and online delivery:
# 0 = No,
# 1 = Yes

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X = scaler.fit_transform(X)

# %%
X
# Out:
# array([[ 0.68245467,  2.37580817, -0.68444887,  1.10998719],
#        [ 0.83499831,  2.37580817, -0.68444887,  1.10998719],
#        [ 5.10622028,  2.37580817, -0.68444887,  2.1848823 ],
#        ...,
#        [-0.7362012 , -0.4209094 , -0.68444887,  2.1848823 ],
#        [-0.81247302, -0.4209094 , -0.68444887,  2.1848823 ],
#        [-0.91162639, -0.4209094 , -0.68444887,  0.03509208]])

# %% [markdown]
# Model Building

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# %%
def modelresults(predictions):
    print("Mean absolute error on model is {}".format(mean_absolute_error(y_test, predictions)))
    print("Root mean squared error on model is {}".format(np.sqrt(mean_squared_error(y_test, predictions))))

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
lr_predictions = lr.predict(X_test)
modelresults(lr_predictions)
# Out:
# Mean absolute error on model is 0.4022201231931877
# Root mean squared error on model is 0.5079514315960864

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
svrmodel = SVR()
svr_param_grid = {"C" : [0.01,0.05], "kernel" : ["linear","poly"], "degree": [2]}
svr_grid_search = GridSearchCV(svrmodel, svr_param_grid)
svr_grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [0.01, 0.05], 'degree': [2],
#                          'kernel': ['linear', 'poly']})

# %%
svr_predictons = svr_grid_search.predict(X_test)
modelresults(svr_predictons)
# Out:
# Mean absolute error on model is 0.4019876158201351
# Root mean squared error on model is 0.5111062620975764

# %%
from sklearn.tree import DecisionTreeRegressor
treemodel = DecisionTreeRegressor()
tree_param_grid = {"max_depth" : [10,30], "min_samples_leaf" : [1,2], "min_samples_split" : [2,5]}
tree_grid_search = GridSearchCV(estimator = treemodel, param_grid = tree_param_grid)
tree_grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeRegressor(),
#              param_grid={'max_depth': [10, 30], 'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5]})

# %%
tree_predictions = tree_grid_search.predict(X_test)
modelresults(tree_predictions)
# Out:
# Mean absolute error on model is 0.3702883074489858
# Root mean squared error on model is 0.4740223246757124

# %%
from sklearn.ensemble import RandomForestRegressor
rfrmodel = RandomForestRegressor()
rfr_param_grid = {"max_depth" : [5,15], "n_estimators" : [2,5,10]}
rfr_grid_search = GridSearchCV(rfrmodel, rfr_param_grid)
rfr_grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [5, 15], 'n_estimators': [2, 5, 10]})

# %%
rfr_predictions = rfr_grid_search.predict(X_test)
modelresults(rfr_predictions)
# Out:
# Mean absolute error on model is 0.36603581698933413
# Root mean squared error on model is 0.46714200144188134

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor()
knn_param_grid = {"n_neighbors" : [25,26,27,28]}
knn_grid_search = GridSearchCV(knn, knn_param_grid)
knn_grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=KNeighborsRegressor(),
#              param_grid={'n_neighbors': [25, 26, 27, 28]})

# %%
knn_predictions = knn_grid_search.predict(X_test)
modelresults(knn_predictions)
# Out:
# Mean absolute error on model is 0.37643621956418166
# Root mean squared error on model is 0.47865404596476274

# %%
knn_grid_search.best_params_
# Out:
# {'n_neighbors': 27}

# %%
from sklearn.ensemble import AdaBoostRegressor
ada = AdaBoostRegressor()
ada_param_grid = {"n_estimators" : [50,100,200], "learning_rate" : [0.1,0.5,1]}
ada_grid_search = GridSearchCV(ada,ada_param_grid)
ada_grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=AdaBoostRegressor(),
#              param_grid={'learning_rate': [0.1, 0.5, 1],
#                          'n_estimators': [50, 100, 200]})

# %%
ada_predictions = ada_grid_search.predict(X_test)
modelresults(ada_predictions)
# Out:
# Mean absolute error on model is 0.3799981204327603
# Root mean squared error on model is 0.4784665646878646

# %%
import joblib

# %%
joblib.dump(rfr_grid_search, "resto_model.pkl")
# Out:
# ['resto_model.pkl']

# %%
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']
